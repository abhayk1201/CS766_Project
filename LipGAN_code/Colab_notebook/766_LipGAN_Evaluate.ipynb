# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !git clone https://github.com/Rudrabha/LipGAN.git   --branch fully_pythonic --single-branch
# Out:
# fatal: destination path 'LipGAN' already exists and is not an empty directory.

# %%
# https://colab.research.google.com/drive/1NLUwupCBsB1HrpEmOIHeMgU63sus2LxP

# %%
# !cd /content/gdrive/MyDrive/LipGan1/
# !wget https://drive.google.com/u/0/uc?export=download&confirm=92tx&id=1DtXY5Ei_V6QjrLwfe7YDrmbSCDu6iru1

# %% [markdown]
# https://drive.google.com/file/d/1DtXY5Ei_V6QjrLwfe7YDrmbSCDu6iru1/view

# %% [markdown]
# http://dlib.net/files/mmod_human_face_detector.dat.bz2

# %%
# !cp -ri "/content/gdrive/My Drive/LipGan1/lipgan_residual_mel.h5" /content/LipGAN/logs
# !cp -ri '/content/gdrive/MyDrive/LipGan1/mmod_human_face_detector.dat' /content/LipGAN/logs
# Out:
# cp: overwrite '/content/LipGAN/logs/mmod_human_face_detector.dat'? n

# %%
cat /content/LipGAN/requirements.txt
# Out:
# dlib==19.17.0
# h5py==2.9.0
# Keras==2.2.4
# matplotlib==2.1.0
# numpy==1.13.3
# opencv-python==4.0.0.21
# Pillow==5.4.1
# scikit-image==0.15.0
# scipy==1.0.0
# tensorflow-gpu==1.8.0
# tqdm==4.19.9
# librosa==0.7.0

# %%
# !cd '/content/LipGAN' && pip install -r requirements.txt

# %%
# pip install dlib==19.17.0 h5py==2.9.0 Keras==2.2.4 matplotlib==2.1.0 numpy==1.13.3 opencv-python==4.0.0.21 Pillow==5.4.1 scikit-image==0.15.0 scipy==1.0.0 tensorflow==1.14.0 tensorflow-gpu==1.14.0 tqdm==4.19.9 librosa==0.7.0

# %%
pip install Keras==2.2.4 Pillow==5.4.1 bleach==1.5.0 dlib==19.17.0 h5py==2.9.0 html5lib==0.9999999 keras-applications==1.0.8 librosa==0.7.0 matplotlib==2.1.0 numpy==1.19.1 opencv-python==4.0.0.21 scikit-image==0.15.0 scipy==1.5.2 soundfile==0.10.3.post1 tensorboard==1.14.0 tensorflow-gpu==1.14.0 tqdm==4.19.9

# %%
pip install git+https://www.github.com/keras-team/keras-contrib.git
# Out:
# ...
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-y90ld175
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-y90ld175
# ...
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp37-none-any.whl size=101065 sha256=e639d743284d778d93dabf8e35672316df176c7e78ca106dd0f50504bad0365f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t5vzh0zy/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib

# %% [markdown]
# # Fixing tf version issue.

# %%
# !pip uninstall tensorflow tensorflow-gpu

# %%
pip install numpy==1.19.1 scipy==1.5.2

# %%
# !pip install tensorflow==1.14.0 tensorflow-gpu==1.14.0

# %%
import tensorflow as tf
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
#pip install -U scipy

# %%
# !pip list

# %%
pip install numba==0.48

# %% [markdown]
# # Now lets try!

# %%
# %cd /content/LipGAN
# !python batch_inference.py --checkpoint_path logs/lipgan_residual_mel.h5 --model residual --face "/content/LipGAN/morgen.png" --fps 25 --audio /content/LipGAN/m_kak_bistro.wav --results_dir /content
# Out:
# /content/LipGAN
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !ffmpeg -i ../result_voice.avi output.mp4 -y
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# from google_drive_downloader import GoogleDriveDownloader as gdd

# finetuned_model = "1QwFd8Aa06bfu_OLHNb-3NW38EvNFH8NE"
# e_hat_video = "1_F4dM6ywVtTWAnZn7a_az8HxXiAvf4YN"
# lg = "1DtXY5Ei_V6QjrLwfe7YDrmbSCDu6iru1"
# dl = "11tAkZXulCBHJ6LgVYX8tRa95uXBDDb21"
# gdd.download_file_from_google_drive(file_id=finetuned_model,
#                                     dest_path='./finetuned_model.tar',
#                                     unzip=False)

# gdd.download_file_from_google_drive(file_id=e_hat_video,
#                                     dest_path='./e_hat_video.tar',
#                                     unzip=False)
# gdd.download_file_from_google_drive(file_id=lg,
#                                     dest_path='./lipgan_residual_mel.h5',
#                                     unzip=False)
# gdd.download_file_from_google_drive(file_id=dl,
#                                     dest_path='./mmod_human_face_detector.dat5',
#                                     unzip=False)
