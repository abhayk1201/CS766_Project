# %%
cd /content/drive/MyDrive/Not_Synced
# Out:
# /content/drive/MyDrive/Not_Synced

# %%
#cp /content/drive/MyDrive/LipGan/*.txt .

# %%
#!wget --user lrs372 --password 7D9y8HS6 https://thor.robots.ox.ac.uk/~vgg/data/lip_reading/data2/lrs2_v1_partaa

# %%
#!wget --user lrs372 --password 7D9y8HS6 https://thor.robots.ox.ac.uk/~vgg/data/lip_reading/data2/lrs2_v1_partab

# %%
#!wget --user lrs372 --password 7D9y8HS6 https://thor.robots.ox.ac.uk/~vgg/data/lip_reading/data2/lrs2_v1_partac

# %%
#!wget --user lrs372 --password 7D9y8HS6 https://thor.robots.ox.ac.uk/~vgg/data/lip_reading/data2/lrs2_v1_partad

# %%
#!wget --user lrs372 --password 7D9y8HS6 https://thor.robots.ox.ac.uk/~vgg/data/lip_reading/data2/lrs2_v1_partae #-q --show-progress

# %%
# cat lrs2_v1_parta* > lrs2_v1.tar

# %%
# mv lrs2_v1_parta* part_files_DELETE/

# %%
ls
# Out:
# audio_hparams.py    generator.py        preprocessed_files/  requirements.txt
# audio.py            License.md          preprocess.py        results/
# batch_inference.py  logs/               __pycache__/         train.py
# discriminator.py    lrs2_v1.tar         readme.gdoc          train_unet.py
# filelists/          part_files_DELETE/  README.md

# %%
# !tar -xvf

# %%
# rm -rf mvlrs_v1/pretrain/*

# %%
ls
# Out:
# audio_hparams.py    generator.py   part_files_DELETE/   README.md
# audio.py            License.md     preprocessed_files/  requirements.txt
# batch_inference.py  logs/          preprocess.py        results/
# discriminator.py    lrs2_v1.tar    __pycache__/         train.py
# filelists/          mvlrs_v1_old/  readme.gdoc          train_unet.py
